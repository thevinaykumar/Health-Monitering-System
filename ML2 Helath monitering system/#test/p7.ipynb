# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

movies_data = {
    'movie_id': [1, 2, 3, 4, 5],
    'title': ['Movie A', 'Movie B', 'Movie C', 'Movie D', 'Movie E'],
    'genres': ['Action|Adventure', 'Drama|Romance', 'Action|Sci-Fi', 'Drama|Thriller', 'Comedy']
}

ratings_data = {
    'user_id': [1, 2, 2, 2, 3],
    'movie_id': [1, 2, 3, 4, 5],
    'rating': [5, 4, 4, 3, 5]
}
# Out:
# Movies DataFrame:
#    movie_id    title            genres
# 0         1  Movie A  Action|Adventure
# 1         2  Movie B     Drama|Romance
# 2         3  Movie C     Action|Sci-Fi
# 3         4  Movie D    Drama|Thriller
# 4         5  Movie E            Comedy
#
# Ratings DataFrame:
#    user_id  movie_id  rating
# 0        1         1       5
# 1        2         2       4
# 2        2         3       4
# 3        2         4       3
# 4        3         5       5
