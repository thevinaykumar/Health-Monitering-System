# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=300, centers=4, cluster_std=1.0, random_state=42)

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
labels = kmeans.fit_predict(X)
# Out:
# /Users/vianykumar/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
score = silhouette_score(X, labels)
print(f"Silhouette Score: {score}")
# Out:
# Silhouette Score: 0.7915830011443038

# %%
plt.scatter(X[:, 0],X[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],c="red", marker='x', s=100, label='Centroids')

# %%
plt.title('KMeans Clustering with make_blobs Data')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
